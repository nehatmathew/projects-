# %%
import os
from langchain_community.vectorstores import FAISS
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_openai import AzureChatOpenAI
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain.chains import create_retrieval_chain
from langchain_core.prompts import ChatPromptTemplate
from InstructorEmbedding import INSTRUCTOR
from dotenv import load_dotenv
from langchain.document_loaders import DirectoryLoader, PyMuPDFLoader, UnstructuredExcelLoader, UnstructuredCSVLoader, BSHTMLLoader
from langchain.document_loaders import UnstructuredPDFLoader
# Out:
# /mnt/neha_exploration/uploaded_pdfs/virtual/lib/python3.10/site-packages/InstructorEmbedding/instructor.py:7: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import trange

# %%
load_dotenv("test.env")
# Out:
# True

# %%
# Initialize LLM (Azure OpenAI)
llm = AzureChatOpenAI(
    azure_deployment=os.getenv("MODEL"),
    azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"),
    openai_api_key=os.getenv("OPENAI_API_KEY"),
    api_version=os.getenv("AZURE_OPENAI_API_VERSION"),
    verbose=False,
    temperature=0.3,
)

# %%
# Check LLM is working
response = llm.invoke("Tell me a motivational quote")
print(response)
# Out:
# content='"Success is not final, failure is not fatal: It is the courage to continue that counts." — Winston Churchill' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 24, 'prompt_tokens': 12, 'total_tokens': 36, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_ded0d14823', 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'finish_reason': 'stop', 'logprobs': None, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}} id='run-a58f9008-eed7-4109-8bf2-4b4e12ec10e5-0' usage_metadata={'input_tokens': 12, 'output_tokens': 24, 'total_tokens': 36, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
# Step 1: Load Documents from Multiple Folders
def load_documents(directory_path):
    # Define document types and their corresponding loaders
    document_types = {
        "**/*.pdf": UnstructuredPDFLoader,
        "**/*.html": BSHTMLLoader,
        "**/*.xlsx": UnstructuredExcelLoader,
        "**/*.csv": UnstructuredCSVLoader
    }
    
    docs = []
    for glob, loader_cls in document_types.items():
        loader = DirectoryLoader(
            directory_path,
            glob=glob,
            show_progress=True,
            use_multithreading=True,
            silent_errors=True,
            recursive=True,
            loader_cls=loader_cls
        )
        docs.extend(loader.load())
    
    return docs

# %%
# Load both extracted files and extracted HTML files
docs1 = load_documents("extracted_files")
docs2 = load_documents("extracted_html_files")
# Out:
#   0%|          | 0/184 [00:00<?, ?it/s]CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
#   1%|          | 1/184 [00:03<11:24,  3.74s/it]CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
#   1%|          | 2/184 [00:18<31:40, 10.44s/it]CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
#   2%|▏         | 3/184 [00:21<21:12,  7.03s/it]CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
#   2%|▏         | 4/184 [00:28<20:23,  6.80s/it]CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
#   3%|▎         | 5/184 [00:29<14:01,  4.70s/it]CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
#   3%|▎         | 6/184 [00:33<13:35,  4.58s/it]CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
#   4%|▍         | 7/184 [00:39<14:26,  4.90s/it]CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
#   4%|▍         | 8/184 [00:42<12:38,  4.31s/it]CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
#   5%|▍         | 9/184 [00:48<14:05,  4.83s/it]CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
#   5%|▌         | 10/184 [00:49<10:37,  3.66s/it]CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
#   6%|▌         | 11/184 [00:56<14:06,  4.90s/it]CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
#   7%|▋         | 12/184 [01:00<12:27,  4.34s/it]CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
#   7%|▋         | 13/184 [01:13<20:26,  7.17s/it]CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
#   8%|▊         | 14/184 [01:14<15:05,  5.33s/it]CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
#   8%|▊         | 15/184 [01:18<13:20,  4.74s/it]CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
#   9%|▊         | 16/184 [01:21<12:08,  4.34s/it]CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
#   9%|▉         | 17/184 [01:22<09:03,  3.25s/it]CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# The PDF <_io.BufferedReader name='extracted_files/corporateresponsibilityperformancereportfy17.pdf'> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. Use the check_extractable if you want to raise an error in this case
/it]CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# Error loading file extracted_files/half-year-report-and-accounts-hy12.pdf: Unable to get page count. Is poppler installed and in PATH?
#  90%|█████████ | 166/184 [19:00<01:28,  4.90s/it]CropBox missing from /Page, defaulting to MediaBox
#  91%|█████████ | 167/184 [19:00<01:02,  3.67s/it]CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
#  91%|█████████▏| 168/184 [19:03<00:51,  3.23s/it]CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
#  92%|█████████▏| 169/184 [19:05<00:43,  2.89s/it]CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
#  95%|█████████▌| 175/184 [19:34<00:58,  6.51s/it]CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
#  96%|█████████▌| 176/184 [19:45<01:01,  7.63s/it]CropBox missing from /Page, defaulting to MediaBox
#  97%|█████████▋| 179/184 [19:48<00:17,  3.42s/it]CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
#  98%|█████████▊| 180/184 [19:54<00:17,  4.31s/it]CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
#  98%|█████████▊| 181/184 [19:57<00:11,  3.79s/it]CropBox missing from /Page, defaulting to MediaBox
#  99%|█████████▉| 182/184 [19:57<00:05,  2.71s/it]CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# 100%|██████████| 184/184 [20:00<00:00,  6.52s/it]
# 0it [00:00, ?it/s]
# 100%|██████████| 4/4 [00:01<00:00,  2.31it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 100%|██████████| 9/9 [00:00<00:00, 51.26it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]

# %%
# Combine all loaded documents
all_documents = docs1 + docs2

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000,chunk_overlap=200)
split_documents = text_splitter.split_documents(all_documents)

# %%
# Initialize Instructor Embedding model
instructor_model = INSTRUCTOR('hkunlp/instructor-base')
# Out:
# load INSTRUCTOR_Transformer
# max_seq_length  512

# %%
def create_embeddings(text_chunks):
    # Ensure each input follows the INSTRUCTOR format
    sample_data = [("Represent this document for retrieval", text.strip()) for text in text_chunks]


    # Debugging: Print first few samples
    print("Sample Input to INSTRUCTOR:", sample_data[:3])

    # Encode with Instructor Model (try batch_size=8 to avoid memory issues)
    embeddings = instructor_model.encode(sample_data, batch_size=8, show_progress_bar=True)
  

    return embeddings.tolist()

# %%
text_chunks = [str(doc.page_content) for doc in split_documents if doc.page_content]

# Debugging: Print first 3 text chunks before encoding
print("First 3 text chunks:", text_chunks[:3])

# Generate embeddings
embeddings = create_embeddings(text_chunks)
# Out:
# First 3 text chunks: ['R3 Security and Resilience Policy\n\nThe nature and breadth of our business means we are vulnerable to situations that can potentially impact the wellbeing of our people, disrupt our business and threaten the attainment of our strategic objectives.\n\nWe are committed to applying our R3 security and resilience management system to ensure we are adequately prepared to mitigate and manage the impact of any critical incident situation or R3 event.\n\nIn pursuing this commitment, we will:\n\nComply with applicable laws, regulations and governance standards in all areas\n\nwhere we operate\n\nApply risk management with an emphasis on preventative and preparatory actions,\n\nto effectively identify, monitor and manage our areas of exposure\n\nDevelop and maintain risk-appropriate security, response and recovery plans and\n\nsupport resources\n\nProvide regular training for our people responsible for managing declared R3 events\n\nAppoint authorized spokespersons in line with our ‘Crisis Communications Policy’', 'support resources\n\nProvide regular training for our people responsible for managing declared R3 events\n\nAppoint authorized spokespersons in line with our ‘Crisis Communications Policy’\n\nIn managing any declared R3 event, our priorities are to:\n\nEnsure the safety, security, health and wellbeing of our people\n\nMinimize environmental impact\n\nSafeguard our reputation and commercial viability\n\nProtect our property and assets\n\nRe-establish business operation\n\nWe are all responsible for ensuring this policy is implemented effectively.\n\nChris Ashton Chief Executive Officer\n\nJune 2022\n\nMS-RT-POL-0002 Rev 1 1 June 2022', 'Second-Party Opinion Worley Limited Sustainability-Linked Bond Framework\n\nEvaluation Summary\n\nEvaluation Date May 18th, 2021 Issuer Location\n\nSydney, Australia\n\nSustainalytics is of the opinion that the Worley Limited Sustainability-Linked Bond Framework aligns with the Sustainability-Linked Bond Principles 2020. This assessment is based on the following:\n\nSelection of Key Performance Indicators (KPIs) Worley Limited Sustainability-Linked Bond Framework includes one KPI, absolute Scope 1 and 2 emissions for the operationally controlled entities and assets of Worley Group (see Table 1). Sustainalytics considers the KPI to be adequate given that it directly measures emissions, follows an external methodology, and can be benchmarked, and based on a consideration of the proportion of Worley’s total GHG emissions that it accounts for.\n\nThe SPTs contribute to the following SDGs:']
# Sample Input to INSTRUCTOR: [('Represent this document for retrieval', 'R3 Security and Resilience Policy\n\nThe nature and breadth of our business means we are vulnerable to situations that can potentially impact the wellbeing of our people, disrupt our business and threaten the attainment of our strategic objectives.\n\nWe are committed to applying our R3 security and resilience management system to ensure we are adequately prepared to mitigate and manage the impact of any critical incident situation or R3 event.\n\nIn pursuing this commitment, we will:\n\nComply with applicable laws, regulations and governance standards in all areas\n\nwhere we operate\n\nApply risk management with an emphasis on preventative and preparatory actions,\n\nto effectively identify, monitor and manage our areas of exposure\n\nDevelop and maintain risk-appropriate security, response and recovery plans and\n\nsupport resources\n\nProvide regular training for our people responsible for managing declared R3 events\n\nAppoint authorized spokespersons in line with our ‘Crisis Communications Policy’'), ('Represent this document for retrieval', 'support resources\n\nProvide regular training for our people responsible for managing declared R3 events\n\nAppoint authorized spokespersons in line with our ‘Crisis Communications Policy’\n\nIn managing any declared R3 event, our priorities are to:\n\nEnsure the safety, security, health and wellbeing of our people\n\nMinimize environmental impact\n\nSafeguard our reputation and commercial viability\n\nProtect our property and assets\n\nRe-establish business operation\n\nWe are all responsible for ensuring this policy is implemented effectively.\n\nChris Ashton Chief Executive Officer\n\nJune 2022\n\nMS-RT-POL-0002 Rev 1 1 June 2022'), ('Represent this document for retrieval', 'Second-Party Opinion Worley Limited Sustainability-Linked Bond Framework\n\nEvaluation Summary\n\nEvaluation Date May 18th, 2021 Issuer Location\n\nSydney, Australia\n\nSustainalytics is of the opinion that the Worley Limited Sustainability-Linked Bond Framework aligns with the Sustainability-Linked Bond Principles 2020. This assessment is based on the following:\n\nSelection of Key Performance Indicators (KPIs) Worley Limited Sustainability-Linked Bond Framework includes one KPI, absolute Scope 1 and 2 emissions for the operationally controlled entities and assets of Worley Group (see Table 1). Sustainalytics considers the KPI to be adequate given that it directly measures emissions, follows an external methodology, and can be benchmarked, and based on a consideration of the proportion of Worley’s total GHG emissions that it accounts for.\n\nThe SPTs contribute to the following SDGs:')]
# Batches:   0%|          | 0/1593 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 7
#       4 print("First 3 text chunks:", text_chunks[:3])
#       6 # Generate embeddings
# ----> 7 embeddings = create_embeddings(text_chunks)
#
# Cell In[23], line 10, in create_embeddings(text_chunks)
#       7 print("Sample Input to INSTRUCTOR:", sample_data[:3])
#       9 # Encode with Instructor Model (try batch_size=8 to avoid memory issues)
# ---> 10 embeddings = instructor_model.encode(sample_data, batch_size=8, show_progress_bar=True)
#      13 return embeddings.tolist()
#
# File /mnt/neha_exploration/uploaded_pdfs/virtual/lib/python3.10/site-packages/InstructorEmbedding/instructor.py:535, in INSTRUCTOR.encode(self, sentences, batch_size, show_progress_bar, output_value, convert_to_numpy, convert_to_tensor, device, normalize_embeddings)
#     533 for start_index in trange(0, len(sentences), batch_size, desc="Batches", disable=not show_progress_bar):
#     534     sentences_batch = sentences_sorted[start_index:start_index+batch_size]
# --> 535     features = self.tokenize(sentences_batch)
#     536     features = batch_to_device(features, device)
#     538     with torch.no_grad():
#
# File /mnt/neha_exploration/uploaded_pdfs/virtual/lib/python3.10/site-packages/sentence_transformers/SentenceTransformer.py:319, in SentenceTransformer.tokenize(self, texts)
#     315 def tokenize(self, texts: Union[List[str], List[Dict], List[Tuple[str, str]]]):
#     316     """
#     317     Tokenizes the texts
#     318     """
# --> 319     return self._first_module().tokenize(texts)
#
# File /mnt/neha_exploration/uploaded_pdfs/virtual/lib/python3.10/site-packages/InstructorEmbedding/instructor.py:378, in INSTRUCTOR_Transformer.tokenize(self, texts)
#     360             tokenized['context_masks'][my_idx] = 0
#     361     # text_types = [pair[-1] for pair in texts]
#     362     # print(text_types)
#     363     # assert all([tid==1 for tid in text_types]) or all([tid==0 for tid in text_types])
#    (...)
#     376     #     raise ValueError('tokenization error')
#     377 else:
# --> 378     raise ValueError('not support other modes')
#     379     # batch1, batch2 = [], []
#     380     # for text_tuple in texts:
#     381     #     batch1.append(text_tuple[0])
#     382     #     batch2.append(text_tuple[1])
#     383     # to_tokenize = [batch1, batch2]
#     385 output.update(tokenized)
#
# ValueError: not support other modes

# %%
# Convert documents into text chunks for embedding
text_chunks = [str(doc.page_content) for doc in split_documents if doc.page_content]
embeddings = create_embeddings(text_chunks)

# %%
# Convert text chunks into LangChain Document format
documents = [Document(page_content=text) for text in text_chunks]

# %%
# Store embeddings in FAISS
db = FAISS.from_embeddings(embeddings, documents)

# %%
# Save FAISS database
db.save_local("faiss-db")

# %%
# Load vector store
new_vectorstore = FAISS.load_local("faiss-db", allow_dangerous_deserialization=True)

# %%
# Retrieval-Augmented Generation (RAG) setup
system_prompt = (
    "Use the given context to answer the question. "
    "If context is different from the question, say you don't know. "
    "Use three sentences maximum and keep the answer concise. "
    "Context: {context}"
)

# %%
retrieval_qa_chat_prompt = ChatPromptTemplate.from_messages([
    ("system", system_prompt),
    ("human", "{input}"),
])

# %%
combine_docs_chain = create_stuff_documents_chain(llm, retrieval_qa_chat_prompt)
retrieval_chain = create_retrieval_chain(new_vectorstore.as_retriever(), combine_docs_chain)

# %%
# Example Query
query = "What is RAG?"
response = retrieval_chain.invoke({"input": query})
print(response["answer"])
